# %% [markdown]
# <a href="https://colab.research.google.com/github/YSHS-APCSP-2526/text-based-adventure-213301/blob/main/Text_Based_Adventure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Requirements for text based adventure
# 1. You must have at least 2 different "paths" that are at least 4 decisions in length
# 2. Include an element of randomness (from the random library)
# 3. Include a list that is core to the text based adventure
# 4. Include a function that is called within your program that includes a while loop, and a parameter that influences a conditional statement in your function.
# 5. Commented Code.
# 6. A [digital flowchart](https://docs.google.com/document/d/1p2k3wL6gzjYWBuWxwEQptmbbOZZNsQrthlC12SNtYgY/edit?usp=sharing) that follows accepted symbols for representing code. You can use google slides or [draw.io](https://www.drawio.com/) for the flowchart.

# %%
import time
#inputs
def intro():
    print("You at the vault door and you need to type in the correct 3 digit code- hint= !@#")
    code = input('input code:   ')
    if code=='123':
        print("You have now entered the vault") #outputs
        time.sleep(2)
        vault()
def vault(): #inputs
    import random
    print("You will either have a chance to get gold, cash , or Nothing ")
    choiceList = ["gold", "cash", "Nothing"]
    choice = random.choice(choiceList) #listing and randomness
    if choice == "gold":        #outputs
      print("You took the gold and must exit thruogh the front lobby")
      lobby()
    if choice == "cash":
      print("You took the cash and can exit way quicker and not get caught move to the vents")
      vents()
    if choice == "Nothing":
      print("GAME OVER THERE IS NOTHING TO HEIST -1000 AURA")
def lobby():
    print("You took the gold and are now in the lobby you must type in the sercurity code to not get caught/ hint= famouse numerical meme" )
    secuirty_code = input('input sercurity_code')
    if secuirty_code=='67':
      print("You have cleared the cameras so you wont get caught")
      exitDoor()
def exitDoor():
  count=3
  correctCode = False
  while correctCode == False: #while loop!!!!
    print("You have cleared cameras but the exit door is locked, what is the code to get EXIT: Hint- Famous Porsche model! ")
    exit_code = input('input Exit door code ')
    if exit_code=='911' and count >0:
      print("You have opend the exit door but it leads to the garage door that is locked")
      correctCode = True
      garage()
    else:
        count -= 1
        print("Incorrect. You have ", count, " more guesses")

def garage(): #inputs
  count=3
  correctCode = False
  while correctCode == False:
    print(" NOW the code is a riddle you need to answer / What building has the most stories- hint= @ook")
    exit_code = input('input garage door code ')
    if exit_code=='library' and count >0:         #outputs
      print("CONGRATS ON MAKING IT TO THE GET AWAY CAR AND ESCAPING YOU WIN!")
      correctCode = True
      complete()
    else:
        count -= 1
        print("Incorrect. You have ", count, " more guesses")

def vents():
  count=3
  correctCode = False
  while correctCode == False: #while loops
    print("You have the cash and will exit through the vents, but the vents have a locked code on them- the hint is the white house adress")
    password=input('input password')
    if password=='1600'and count >0:
      print("You have opened the vents exit now!")
      roof_door()
    else:
      count -= 1
      print("Incorrect. You have ", count, " more guesses")

def roof_door():
  roofCount=3
  correctCode = False
  print("You have made it through the vents to the roof door you must now type in the correct code to exit. hint= $!&*$^^@#  ")
  code=input('input roof door code')

  while correctCode == False and roofCount>=0:
    if code== '417846623' and roofCount > 0:
      print("YOU HAVE ESCAPED AND EXITED ON THE HELI COPPTER (MISSION COMPLTE)")
      correctCode=True
      helicopter()

    elif roofCount > 0:
      roofCount -=1
      print("Inccort. You have", roofCount, "more guesses")
      code=input('input roof door code')

    else:
      print("GAME OVER")
      break
def helicopter():
  print("CONGRADUALTIONS YOU HAVE MADE IT TO THE HELI COHPPER AND SUCCESFULLY COMPLETED THE HEIST + 1000 AURA")
def complete():
  print("YOU HAVE COMPLTED THE MISSON!!!!")

# %%
def main():
  intro()

# %%
main()
# Out:
# You at the vault door and you need to type in the correct 3 digit code- hint= !@#
# input code:   123
# You have now entered the vault
# You will either have a chance to get gold, cash , or Nothing
# You took the cash and can exit way quicker and not get caught move to the vents
# You have the cash and will exit through the vents, but the vents have a locked code on them- the hint is the white house adress
# input password1600
# You have opened the vents exit now!
# You have made it through the vents to the roof door you must now type in the correct code to exit. hint= $!&*$^^@#
# input roof door code41784662
# Inccort. You have 2 more guesses
# input roof door code417846623
# YOU HAVE ESCAPED AND EXITED ON THE HELI COPPTER (MISSION COMPLTE)
# CONGRADUALTIONS YOU HAVE MADE IT TO THE HELI COHPPER AND SUCCESFULLY COMPLETED THE HEIST + 1000 AURA
# You have the cash and will exit through the vents, but the vents have a locked code on them- the hint is the white house adress
